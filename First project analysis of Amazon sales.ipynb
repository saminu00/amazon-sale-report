# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Desktop\portfolio file\Amazon Sale Report.csv")

df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2240\2884100650.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\user\Desktop\portfolio file\Amazon Sale Report.csv")
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# ...

# %%
df = df.drop(columns=['Unnamed: 22', 'B2B', 'promotion-ids'])

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency                  0
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# fulfilled-by          89698
# dtype: int64

# %%
df['Courier Status'] = df['Courier Status'].fillna('Unknown')

# %%
most_frequent_currency = df['currency'].mode()[0]
df['currency'] = df['currency'].fillna(most_frequent_currency)

# %%
median_amount = df['Amount'].median()
df['Amount'] = df['Amount'].fillna(median_amount)

# %%
df['ship-city'] = df['ship-city'].fillna('Unknown')
df['ship-state'] = df['ship-state'].fillna('Unknown')
df['ship-postal-code'] = df['ship-postal-code'].fillna('Unknown')
df['ship-country'] = df['ship-country'].fillna('Unknown')

# %%
df['fulfilled-by'] = df['fulfilled-by'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# fulfilled-by          0
# dtype: int64

# %%
if 'Amount_total_sales' not in df.columns:
    df['Amount_total_sales'] = df['Qty'] * df['Amount']

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2240\2394721818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df.rename(columns=lambda x: x.strip().lower().replace(' ', '_'), inplace=True)

# %%
df['Amount'] = pd.to_numeric(data['Amount'], errors='coerce')

# %%
df
# Out:
#          index             order_id       date                        status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  128974  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
import numpy as np
df['sales_category'] = pd.cut(
    df['amount_total_sales'], bins=[0, 500, 1000, np.inf], labels=['Low', 'Medium', 'High']
)

# %%
df.to_csv('cleaned_sales_data.csv', index=False)

print("Data cleaning and transformation complete. File saved as 'cleaned_sales_data.csv'")
# Out:
# Data cleaning and transformation complete. File saved as 'cleaned_sales_data.csv'

# %%
df.to_csv('cleaned_sales_data.csv', index=False)

print("Data cleaning and transformation complete. File saved as 'cleaned_sales_data.csv'.")
# Out:
# Data cleaning and transformation complete. File saved as 'cleaned_sales_data.csv'.

# %%
import os
print(os.getcwd())
